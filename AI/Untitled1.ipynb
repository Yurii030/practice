# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#       2 import pandas as pd
#       3 import numpy as np
#
# File C:\ProgramData\Anaconda3\envs\ojt\lib\site-packages\sklearn\linear_model\__init__.py:11
#       9 from ._base import LinearRegression
#      10 from ._bayes import BayesianRidge, ARDRegression
# ---> 11 from ._least_angle import (
#      12     Lars,
#      13     LassoLars,
#      14     lars_path,
#      15     lars_path_gram,
#      16     LarsCV,
#      17     LassoLarsCV,
#      18     LassoLarsIC,
#      19 )
#      20 from ._coordinate_descent import (
#      21     Lasso,
#      22     ElasticNet,
#    (...)
#      30     MultiTaskLassoCV,
#      31 )
#      32 from ._glm import PoissonRegressor, GammaRegressor, TweedieRegressor
#
# ...
